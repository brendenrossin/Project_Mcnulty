# %% [markdown]
# ## CREATING THE PICKLE FILE

# %%
import csv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import RidgeCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.cross_validation import KFold
from sklearn.model_selection import learning_curve
import matplotlib.style as style
style.use('fivethirtyeight')
# %matplotlib inline
# Out:
# /Users/brendenrossin/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
f=open('AviationData.txt')

aviation_data=f.readlines()
aviation_list=[]
lax=[]

for line in aviation_data:
    aviation_list.append(line.split(" | "))

for line in aviation_list:
    if 'LAX94LA336' in line:
        lax.append(line)
print(lax)
# Out:
# [['20001218X45447', 'Accident', 'LAX94LA336', '07/19/1962', 'BRIDGEPORT, CA', 'United States', '', '', '', '', 'Fatal(4)', 'Destroyed', '', 'N5069P', 'PIPER', 'PA24-180', 'No', '1', 'Reciprocating', '', '', 'Personal', '', '4', '0', '0', '0', 'UNK', 'UNKNOWN', 'Probable Cause', '09/19/1996', '\n']]

# %%
print(aviation_list[0:5])
# Out:
# [['Event Id', 'Investigation Type', 'Accident Number', 'Event Date', 'Location', 'Country', 'Latitude', 'Longitude', 'Airport Code', 'Airport Name', 'Injury Severity', 'Aircraft Damage', 'Aircraft Category', 'Registration Number', 'Make', 'Model', 'Amateur Built', 'Number of Engines', 'Engine Type', 'FAR Description', 'Schedule', 'Purpose of Flight', 'Air Carrier', 'Total Fatal Injuries', 'Total Serious Injuries', 'Total Minor Injuries', 'Total Uninjured', 'Weather Condition', 'Broad Phase of Flight', 'Report Status', 'Publication Date', '\n'], ['20180719X01751', 'Accident', 'CEN18LA281', '07/19/2018', 'Shreveport, LA', 'United States', '32.540277', '-93.745000', 'DTN', 'Shreveport Executive', 'Non-Fatal', 'Substantial', 'Airplane', 'N7080F', 'PIPER', 'PA28', 'No', '1', 'Reciprocating', 'Part 91: General Aviation', '', 'Personal', '', '', '', '', '1', 'VMC', 'MANEUVERING', 'Preliminary', '07/23/2018', '\n'], ['20180717X23051', 'Accident', 'GAA18CA428', '07/17/2018', 'Nashville, TN', 
# ...

# %%
aviation = [i[:-1] for i in aviation_list]

# %%
aviation[0:5]
# Out:
# [['Event Id',
#   'Investigation Type',
#   'Accident Number',
#   'Event Date',
#   'Location',
#   'Country',
#   'Latitude',
#   'Longitude',
#   'Airport Code',
#   'Airport Name',
#   'Injury Severity',
#   'Aircraft Damage',
#   'Aircraft Category',
#   'Registration Number',
#   'Make',
#   'Model',
#   'Amateur Built',
#   'Number of Engines',
#   'Engine Type',
#   'FAR Description',
#   'Schedule',
#   'Purpose of Flight',
#   'Air Carrier',
#   'Total Fatal Injuries',
#   'Total Serious Injuries',
#   'Total Minor Injuries',
#   'Total Uninjured',
#   'Weather Condition',
#   'Broad Phase of Flight',
#   'Report Status',
#   'Publication Date'],
#  ['20180719X01751',
#   'Accident',
#   'CEN18LA281',
#   '07/19/2018',
#   'Shreveport, LA',
#   'United States',
#   '32.540277',
#   '-93.745000',
#   'DTN',
#   'Shreveport Executive',
#   'Non-Fatal',
#   'Substantial',
#   'Airplane',
#   'N7080F',
#   'PIPER',
#   'PA28',
#   'No',
#   '1',
#   'Reciprocating',
# ...

# %%
headers = aviation.pop(0)
df = pd.DataFrame(aviation, columns=headers)

# %%
df.head()
# Out:
#          Event Id Investigation Type Accident Number  Event Date  \
# 0  20180719X01751           Accident      CEN18LA281  07/19/2018
# 1  20180717X23051           Accident      GAA18CA428  07/17/2018
# 2  20180717X82154           Accident      CEN18LA276  07/17/2018
# 3  20180716X44947           Accident      GAA18CA427  07/16/2018
# 4  20180716X60511           Accident      GAA18CA424  07/16/2018
#
#          Location        Country   Latitude   Longitude Airport Code  \
# 0  Shreveport, LA  United States  32.540277  -93.745000          DTN
# 1   Nashville, TN  United States  36.124445  -86.678056          BNA
# 2        Katy, TX  United States  29.868056  -95.795000          IWS
# 3   Hollywood, FL  United States  26.002222  -80.240000          HWO
# 4  New Castle, IN  United States  39.564722  -85.235555          N/A
#
#            Airport Name       ...          Purpose of Flight Air Carrier  \
# 0  Shreveport Executive       ...                   Personal
# ...

# %%
df.describe()
# Out:
#               Event Id Investigation Type Accident Number  Event Date  \
# count            81899              81899           81899       81899
# unique           80704                  2           81899       13203
# top     20001214X45071           Accident      CHI87FA021  05/16/1982
# freq                 3              78571               1          25
#
#              Location        Country Latitude Longitude Airport Code  \
# count           81899          81899    81899     81899        81899
# unique          25950            178    19101     20545         9860
# top     ANCHORAGE, AK  United States
# freq              372          76901    53840     53849        35450
#
#        Airport Name       ...        Purpose of Flight Air Carrier  \
# count         81899       ...                    81899       81899
# unique        23307       ...                       23        2958
# top                       ...                 Personal
# ...

# %%
df = df.replace('', np.nan)

# %%
df.describe()
# Out:
#               Event Id Investigation Type Accident Number  Event Date  \
# count            81899              81899           81899       81899
# unique           80704                  2           81899       13203
# top     20001214X45071           Accident      CHI87FA021  05/16/1982
# freq                 3              78571               1          25
#
#              Location        Country   Latitude    Longitude Airport Code  \
# count           81824          81392      28059        28050        46449
# unique          25949            177      19100        20544         9859
# top     ANCHORAGE, AK  United States  33.460833  -112.082500         NONE
# freq              372          76901         29           34         1473
#
#        Airport Name       ...        Purpose of Flight      Air Carrier  \
# count         51554       ...                    77474             4063
# unique        23306       ...                       22             2957
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81899 entries, 0 to 81898
# Data columns (total 31 columns):
# Event Id                  81899 non-null object
# Investigation Type        81899 non-null object
# Accident Number           81899 non-null object
# Event Date                81899 non-null object
# Location                  81824 non-null object
# Country                   81392 non-null object
# Latitude                  28059 non-null object
# Longitude                 28050 non-null object
# Airport Code              46449 non-null object
# Airport Name              51554 non-null object
# Injury Severity           81899 non-null object
# Aircraft Damage           79321 non-null object
# Aircraft Category         25157 non-null object
# Registration Number       78414 non-null object
# Make                      81828 non-null object
# Model                     81800 non-null object
# Amateur Built             81267 non-null object
# ...

# %%
df.columns
# Out:
# Index(['Event Id', 'Investigation Type', 'Accident Number', 'Event Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport Code',
#        'Airport Name', 'Injury Severity', 'Aircraft Damage',
#        'Aircraft Category', 'Registration Number', 'Make', 'Model',
#        'Amateur Built', 'Number of Engines', 'Engine Type', 'FAR Description',
#        'Schedule', 'Purpose of Flight', 'Air Carrier', 'Total Fatal Injuries',
#        'Total Serious Injuries', 'Total Minor Injuries', 'Total Uninjured',
#        'Weather Condition', 'Broad Phase of Flight', 'Report Status',
#        'Publication Date'],
#       dtype='object')

# %%
df.columns = ['Event_Id', 'Investigation_Type', 'Accident_Number', 'Event_Date', 'Location',
              'Country', 'Latitude', 'Longitude', 'Airport_Code', 'Airport_Name', 'Injury_Severity',
              'Aircraft_Damage', 'Aircraft_Category', 'Registration_Number', 'Make', 'Model',
              'Amateur_Built', 'Number_Engines', 'Engine_Type', 'FAR_Description', 'Schedule',
              'Flight_Purpose', 'Air_Carrier', 'Total_Fatal_Injuries', 'Total_Serious_Injuries',
              'Total_Minor_Injuries', 'Total_Uninjured', 'Weather_Condition', 'Broad_Phase_of_Flight',
              'Report_Status', 'Publication_Date']

# %%
import pickle

with open('airline_crash.pkl', 'wb') as picklefile:
    pickle.dump(df, picklefile)

# %% [markdown]
# ## OPENING THE PICKLE FILE

# %%
with open('airline_crash.pkl', 'rb') as picklefile:
    df = pickle.load(picklefile)

# %%
df
# Out:
#              Event_Id Investigation_Type Accident_Number  Event_Date  \
# 0      20180719X01751           Accident      CEN18LA281  07/19/2018
# 1      20180717X23051           Accident      GAA18CA428  07/17/2018
# 2      20180717X82154           Accident      CEN18LA276  07/17/2018
# 3      20180716X44947           Accident      GAA18CA427  07/16/2018
# 4      20180716X60511           Accident      GAA18CA424  07/16/2018
# 5      20180715X83946           Accident      GAA18CA423  07/15/2018
# 6      20180716X21449           Accident      GAA18CA422  07/15/2018
# 7      20180715X13651           Accident      CEN18FA267  07/15/2018
# 8      20180716X64029           Accident      CEN18LA271  07/14/2018
# 9      20180712X20155           Accident      ERA18FA189  07/12/2018
# 10     20180712X91417           Accident      CEN18LA273  07/12/2018
# 11     20180712X55625           Accident      CEN18FA265  07/12/2018
# 12     20180711X93304           Accident      CEN18FA263  07/11/2018
# ...

# %%
df.Weather_Condition.unique()
# Out:
# array(['VMC', nan, 'IMC', 'UNK'], dtype=object)

# %% [markdown]
# ## Weather condition definitions
#
# VMC and IMC are aviation terms used to describe meteorological conditions during flight. VMC stands for visual meteorological conditions, and IMC stands for instrument meteorological conditions.
#
# The definition of IMC, according to the FAA, is meteorological conditions expressed in terms of visibility, distance from clouds, and ceiling less than the minima specified for visual meteorological conditions (VMC).
#
# IMC is any meteorological condition that doesn’t qualify as visual meteorological conditions, or weather conditions worse than VMC.
#
# UNK is most likely unknown.

# %% [markdown]
# ## ACCIDENT VS INCIDENT
#
# In aviation, an accident is defined by the Convention on International Civil Aviation Annex 13 as an occurrence associated with the operation of an aircraft, which takes place from the time any person boards the aircraft with the intention of flight until all such persons have disembarked, and in which a) a person is fatally or seriously injured, b) the aircraft sustains significant damage or structural failure, or c) the aircraft goes missing or becomes completely inaccessible.
#
# Annex 13 defines an incident as an occurrence, other than an accident, associated with the operation of an aircraft which affects or could affect the safety of operation

# %%
df.Total_Uninjured.value_counts()
# Out:
# 1      23328
# 0      19121
# 2      14765
# 3       4069
# 4       2547
# 5        842
# 6        458
# 7        262
# 8        145
# 9        119
# 10       103
# 11        58
# 12        48
# 13        40
# 16        38
# 15        36
# 53        32
# 17        32
# 14        32
# 19        28
# 18        27
# 20        25
# 21        22
# 140       20
# 131       20
# 50        19
# 52        19
# 44        19
# 32        18
# 99        18
#        ...
# 360        1
# 348        1
# 375        1
# 558        1
# 378        1
# 507        1
# 267        1
# 368        1
# 333        1
# 404        1
# 178        1
# 367        1
# 394        1
# 439        1
# 311        1
# 233        1
# 280        1
# 521        1
# 304        1
# 384        1
# 414        1
# 287        1
# 362        1
# 237        1
# 357        1
# 412        1
# 240        1
# 332        1
# 264        1
# 302        1
# Name: Total_Uninjured, Length: 370, dtype: int64

# %%
df.Injury_Severity
# Out:
# 0          Non-Fatal
# 1        Unavailable
# 2          Non-Fatal
# 3          Non-Fatal
# 4          Non-Fatal
# 5          Non-Fatal
# 6          Non-Fatal
# 7           Fatal(2)
# 8          Non-Fatal
# 9           Fatal(1)
# 10         Non-Fatal
# 11          Fatal(1)
# 12          Fatal(1)
# 13         Non-Fatal
# 14         Non-Fatal
# 15          Fatal(1)
# 16         Non-Fatal
# 17         Non-Fatal
# 18         Non-Fatal
# 19         Non-Fatal
# 20         Non-Fatal
# 21          Fatal(1)
# 22         Non-Fatal
# 23          Fatal(2)
# 24         Non-Fatal
# 25         Non-Fatal
# 26         Non-Fatal
# 27         Non-Fatal
# 28         Non-Fatal
# 29         Non-Fatal
#             ...
# 81869       Incident
# 81870       Fatal(2)
# 81871      Non-Fatal
# 81872      Non-Fatal
# 81873      Non-Fatal
# 81874       Fatal(8)
# 81875       Fatal(1)
# 81876      Non-Fatal
# 81877      Non-Fatal
# 81878      Non-Fatal
# 81879       Fatal(1)
# 81880       Fatal(1)
# ...

# %%
state_df = pd.concat([df['Event_Id'], df['Location'].str.split(', ', expand=True)], axis=1)

# %%
state_df
# Out:
#              Event_Id                0   1     2     3     4
# 0      20180719X01751       Shreveport  LA  None  None  None
# 1      20180717X23051        Nashville  TN  None  None  None
# 2      20180717X82154             Katy  TX  None  None  None
# 3      20180716X44947        Hollywood  FL  None  None  None
# 4      20180716X60511       New Castle  IN  None  None  None
# 5      20180715X83946         Lowville  NY  None  None  None
# 6      20180716X21449           Palmer  AK  None  None  None
# 7      20180715X13651         La Porte  TX  None  None  None
# 8      20180716X64029        Lexington  TX  None  None  None
# 9      20180712X20155       Plainville  CT  None  None  None
# 10     20180712X91417         Rockford  OH  None  None  None
# 11     20180712X55625            Rhome  TX  None  None  None
# 12     20180711X93304         Wheatley  AR  None  None  None
# 13     20180711X41922          Houston  TX  None  None  None
# ...

# %%
state_df['City'] = state_df[0]
state_df['State'] = state_df[1]

state_df = state_df.drop([0,1,2,3,4],1)

# %%
state_df
# Out:
#              Event_Id             City State
# 0      20180719X01751       Shreveport    LA
# 1      20180717X23051        Nashville    TN
# 2      20180717X82154             Katy    TX
# 3      20180716X44947        Hollywood    FL
# 4      20180716X60511       New Castle    IN
# 5      20180715X83946         Lowville    NY
# 6      20180716X21449           Palmer    AK
# 7      20180715X13651         La Porte    TX
# 8      20180716X64029        Lexington    TX
# 9      20180712X20155       Plainville    CT
# 10     20180712X91417         Rockford    OH
# 11     20180712X55625            Rhome    TX
# 12     20180711X93304         Wheatley    AR
# 13     20180711X41922          Houston    TX
# 14     20180711X44318          De Land    IL
# 15     20180710X25659         Moriarty    NM
# 16     20180711X04255         Hydaburg    AK
# 17     20180709X82138           Colusa    CA
# 18     20180710X75535             Rulo    NE
# 19     20180709X81705  Fort Lauderdale    FL
# ...

# %%
df.reset_index(inplace=True)
state_df.reset_index(inplace=True)

# %%
state_df
# Out:
#        index        Event_Id             City State
# 0          0  20180719X01751       Shreveport    LA
# 1          1  20180717X23051        Nashville    TN
# 2          2  20180717X82154             Katy    TX
# 3          3  20180716X44947        Hollywood    FL
# 4          4  20180716X60511       New Castle    IN
# 5          5  20180715X83946         Lowville    NY
# 6          6  20180716X21449           Palmer    AK
# 7          7  20180715X13651         La Porte    TX
# 8          8  20180716X64029        Lexington    TX
# 9          9  20180712X20155       Plainville    CT
# 10        10  20180712X91417         Rockford    OH
# 11        11  20180712X55625            Rhome    TX
# 12        12  20180711X93304         Wheatley    AR
# 13        13  20180711X41922          Houston    TX
# 14        14  20180711X44318          De Land    IL
# 15        15  20180710X25659         Moriarty    NM
# 16        16  20180711X04255         Hydaburg    AK
# ...

# %%
df = pd.merge(df, state_df, on='index')

df = df.drop(['Location'],1)

# %%
df.set_index('index', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81899 entries, 0 to 81898
# Data columns (total 33 columns):
# Event_Id_x                81899 non-null object
# Investigation_Type        81899 non-null object
# Accident_Number           81899 non-null object
# Event_Date                81899 non-null object
# Country                   81392 non-null object
# Latitude                  28059 non-null object
# Longitude                 28050 non-null object
# Airport_Code              46449 non-null object
# Airport_Name              51554 non-null object
# Injury_Severity           81899 non-null object
# Aircraft_Damage           79321 non-null object
# Aircraft_Category         25157 non-null object
# Registration_Number       78414 non-null object
# Make                      81828 non-null object
# Model                     81800 non-null object
# Amateur_Built             81267 non-null object
# Number_Engines            77419 non-null object
# ...

# %%
df.Aircraft_Damage.value_counts()
# Out:
# Substantial    59046
# Destroyed      17680
# Minor           2595
# Name: Aircraft_Damage, dtype: int64

# %%
df['Event_Date'].head()
# Out:
# index
# 0    07/19/2018
# 1    07/17/2018
# 2    07/17/2018
# 3    07/16/2018
# 4    07/16/2018
# Name: Event_Date, dtype: object

# %%
df.Latitude = df.Latitude.astype('float')
df.Longitude = df.Longitude.astype('float')
df.Total_Fatal_Injuries = df.Total_Fatal_Injuries.astype('float')
df.Total_Serious_Injuries = df.Total_Serious_Injuries.astype('float')
df.Total_Minor_Injuries = df.Total_Minor_Injuries.astype('float')
df.Total_Uninjured = df.Total_Uninjured.astype('float')
df.Number_Engines = df.Number_Engines.astype('float')

df['Event_Date'] = pd.to_datetime(df['Event_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81899 entries, 0 to 81898
# Data columns (total 33 columns):
# Event_Id_x                81899 non-null object
# Investigation_Type        81899 non-null object
# Accident_Number           81899 non-null object
# Event_Date                81899 non-null datetime64[ns]
# Country                   81392 non-null object
# Latitude                  28059 non-null float64
# Longitude                 28050 non-null float64
# Airport_Code              46449 non-null object
# Airport_Name              51554 non-null object
# Injury_Severity           81899 non-null object
# Aircraft_Damage           79321 non-null object
# Aircraft_Category         25157 non-null object
# Registration_Number       78414 non-null object
# Make                      81828 non-null object
# Model                     81800 non-null object
# Amateur_Built             81267 non-null object
# Number_Engines            77419 non-null float64
# ...

# %%
df.describe()
# Out:
#            Latitude     Longitude  Number_Engines  Total_Fatal_Injuries  \
# count  28059.000000  28050.000000    77419.000000          56503.000000
# mean      37.598733    -93.418193        1.147419              0.827425
# std       12.277073     39.827566        0.448006              6.216636
# min      -78.016945   -178.676111        0.000000              0.000000
# 25%       33.351667   -114.938194        1.000000              0.000000
# 50%       38.148889    -94.371389        1.000000              0.000000
# 75%       42.531111    -81.630069        1.000000              1.000000
# max       89.218056    177.557778        4.000000            349.000000
#
#        Total_Serious_Injuries  Total_Minor_Injuries  Total_Uninjured
# count            54055.000000          55224.000000     68447.000000
# mean                 0.324262              0.510955         5.872485
# std                  1.372970              2.775717        29.465923
# ...

# %%
df.Total_Uninjured.max
# Out:
# <bound method Series.max of index
# 0         1.0
# 1         NaN
# 2         1.0
# 3         NaN
# 4         NaN
# 5         1.0
# 6         1.0
# 7         NaN
# 8         1.0
# 9         NaN
# 10        1.0
# 11        NaN
# 12        NaN
# 13        3.0
# 14        1.0
# 15        NaN
# 16        1.0
# 17        1.0
# 18        1.0
# 19        2.0
# 20        2.0
# 21        NaN
# 22        3.0
# 23        NaN
# 24        1.0
# 25        1.0
# 26        NaN
# 27        1.0
# 28        NaN
# 29        1.0
#          ...
# 81869     1.0
# 81870     0.0
# 81871     0.0
# 81872     0.0
# 81873     1.0
# 81874     0.0
# 81875     0.0
# 81876     1.0
# 81877     2.0
# 81878     0.0
# 81879     0.0
# 81880     0.0
# 81881     0.0
# 81882     1.0
# 81883     1.0
# 81884     2.0
# 81885     1.0
# 81886     0.0
# 81887     2.0
# 81888     2.0
# 81889     0.0
# 81890     1.0
# 81891     1.0
# 81892     0.0
# 81893    44.0
# 81894     NaN
# 81895     0.0
# 81896     NaN
# 81897     0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81899 entries, 0 to 81898
# Data columns (total 33 columns):
# Event_Id_x                81899 non-null object
# Investigation_Type        81899 non-null object
# Accident_Number           81899 non-null object
# Event_Date                81899 non-null datetime64[ns]
# Country                   81392 non-null object
# Latitude                  28059 non-null float64
# Longitude                 28050 non-null float64
# Airport_Code              46449 non-null object
# Airport_Name              51554 non-null object
# Injury_Severity           81899 non-null object
# Aircraft_Damage           79321 non-null object
# Aircraft_Category         25157 non-null object
# Registration_Number       78414 non-null object
# Make                      81828 non-null object
# Model                     81800 non-null object
# Amateur_Built             81267 non-null object
# Number_Engines            77419 non-null float64
# ...

# %%
real_df = df.dropna(subset=['Investigation_Type','Event_Date',
              'Country', 'Injury_Severity',
              'Aircraft_Damage', 'Make', 'Model',
              'Amateur_Built', 'Number_Engines', 'Engine_Type',
              'Flight_Purpose', 'Total_Fatal_Injuries', 'Total_Serious_Injuries',
              'Total_Minor_Injuries', 'Total_Uninjured', 'Weather_Condition', 'Broad_Phase_of_Flight','City','State'])

real_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46408 entries, 16185 to 81898
# Data columns (total 33 columns):
# Event_Id_x                46408 non-null object
# Investigation_Type        46408 non-null object
# Accident_Number           46408 non-null object
# Event_Date                46408 non-null datetime64[ns]
# Country                   46408 non-null object
# Latitude                  286 non-null float64
# Longitude                 286 non-null float64
# Airport_Code              25383 non-null object
# Airport_Name              27551 non-null object
# Injury_Severity           46408 non-null object
# Aircraft_Damage           46408 non-null object
# Aircraft_Category         3674 non-null object
# Registration_Number       46408 non-null object
# Make                      46408 non-null object
# Model                     46408 non-null object
# Amateur_Built             46408 non-null object
# Number_Engines            46408 non-null float64
# ...

# %%
real_df = real_df[['Event_Id_x','Investigation_Type','Event_Date',
              'Country', 'Injury_Severity',
              'Aircraft_Damage', 'Make', 'Model',
              'Amateur_Built', 'Number_Engines', 'Engine_Type',
              'Flight_Purpose', 'Total_Fatal_Injuries', 'Total_Serious_Injuries',
              'Total_Minor_Injuries', 'Total_Uninjured', 'Weather_Condition', 'Broad_Phase_of_Flight','City','State']]

# %%
real_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46408 entries, 16185 to 81898
# Data columns (total 20 columns):
# Event_Id_x                46408 non-null object
# Investigation_Type        46408 non-null object
# Event_Date                46408 non-null datetime64[ns]
# Country                   46408 non-null object
# Injury_Severity           46408 non-null object
# Aircraft_Damage           46408 non-null object
# Make                      46408 non-null object
# Model                     46408 non-null object
# Amateur_Built             46408 non-null object
# Number_Engines            46408 non-null float64
# Engine_Type               46408 non-null object
# Flight_Purpose            46408 non-null object
# Total_Fatal_Injuries      46408 non-null float64
# Total_Serious_Injuries    46408 non-null float64
# Total_Minor_Injuries      46408 non-null float64
# Total_Uninjured           46408 non-null float64
# Weather_Condition         46408 non-null object
# ...

# %%
real_df.describe()
# Out:
#        Number_Engines  Total_Fatal_Injuries  Total_Serious_Injuries  \
# count    46408.000000           46408.00000            46408.000000
# mean         1.132348               0.39866                0.193006
# std          0.407842               2.34053                0.825163
# min          0.000000               0.00000                0.000000
# 25%          1.000000               0.00000                0.000000
# 50%          1.000000               0.00000                0.000000
# 75%          1.000000               0.00000                0.000000
# max          4.000000             230.00000               81.000000
#
#        Total_Minor_Injuries  Total_Uninjured
# count          46408.000000     46408.000000
# mean               0.320871         2.642066
# std                1.392292        16.465298
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# ...

# %%
real_df['Total_Passengers'] = (real_df['Total_Fatal_Injuries'] + real_df['Total_Serious_Injuries'] + 
                                real_df['Total_Minor_Injuries'] + real_df['Total_Uninjured'])

# %%
real_df.describe()
# Out:
#        Number_Engines  Total_Fatal_Injuries  Total_Serious_Injuries  \
# count    46408.000000           46408.00000            46408.000000
# mean         1.132348               0.39866                0.193006
# std          0.407842               2.34053                0.825163
# min          0.000000               0.00000                0.000000
# 25%          1.000000               0.00000                0.000000
# 50%          1.000000               0.00000                0.000000
# 75%          1.000000               0.00000                0.000000
# max          4.000000             230.00000               81.000000
#
#        Total_Minor_Injuries  Total_Uninjured  Total_Passengers
# count          46408.000000     46408.000000      46408.000000
# mean               0.320871         2.642066          3.554603
# std                1.392292        16.465298         16.926774
# min                0.000000         0.000000          0.000000
# ...

# %%
real_df['Broad_Phase_of_Flight'].value_counts()
# Out:
# LANDING        11376
# TAKEOFF         9677
# CRUISE          7778
# MANEUVERING     6342
# APPROACH        4887
# CLIMB           1510
# TAXI            1420
# DESCENT         1332
# GO-AROUND       1056
# STANDING         524
# UNKNOWN          419
# OTHER             87
# Name: Broad_Phase_of_Flight, dtype: int64

# %%
real_df['Total_Fatal_Injuries'].value_counts()
# Out:
# 0.0      37608
# 1.0       4403
# 2.0       2669
# 3.0        801
# 4.0        583
# 5.0        128
# 6.0         97
# 7.0         30
# 8.0         27
# 10.0        11
# 14.0         5
# 9.0          5
# 12.0         3
# 25.0         3
# 11.0         3
# 13.0         2
# 34.0         2
# 82.0         2
# 17.0         2
# 23.0         2
# 18.0         2
# 27.0         1
# 73.0         1
# 43.0         1
# 78.0         1
# 132.0        1
# 156.0        1
# 230.0        1
# 37.0         1
# 135.0        1
# 31.0         1
# 153.0        1
# 68.0         1
# 110.0        1
# 88.0         1
# 20.0         1
# 28.0         1
# 70.0         1
# 111.0        1
# 15.0         1
# 29.0         1
# Name: Total_Fatal_Injuries, dtype: int64

# %%
real_df['Aircraft_Damage'].value_counts()
# Out:
# Substantial    32832
# Destroyed      12286
# Minor           1290
# Name: Aircraft_Damage, dtype: int64

# %%
print(len(real_df['Make'].unique()))
# Out:
# 3448

# %%
real_df['Make'].unique()
# Out:
# array(['PIPER', 'Rans', 'CESSNA', ..., 'BELL/TEXTRON', 'SONS MUSTANG',
#        'BELL HELICOPTER'], dtype=object)

# %%
real_df['Make'] = real_df['Make'].str.upper()

# %%
print(len(real_df['Make'].unique()))
# Out:
# 3131

# %%
real_df['Amateur_Built'].value_counts()
# Out:
# No     42508
# Yes     3900
# Name: Amateur_Built, dtype: int64

# %%
real_df['Flight_Purpose'].value_counts()
# Out:
# Personal                     26992
# Instructional                 5792
# Unknown                       4806
# Aerial Application            3045
# Business                      2841
# Positioning                    743
# Other Work Use                 597
# Ferry                          561
# Public Aircraft                344
# Executive/Corporate            336
# Aerial Observation             329
# Flight Test                      9
# Skydiving                        3
# External Load                    3
# Air Race/Show                    3
# Public Aircraft - Local          2
# Public Aircraft - Federal        1
# Glider Tow                       1
# Name: Flight_Purpose, dtype: int64

# %%
no_deaths = real_df[real_df['Total_Fatal_Injuries'] == 0]

no_deaths
# Out:
#            Event_Id_x Investigation_Type Event_Date        Country  \
# index
# 16185  20081126X30503           Accident 2008-11-25  United States
# 16254  20081112X43029           Accident 2008-11-08  United States
# 16315  20081024X13647           Accident 2008-10-24  United States
# 16337  20081020X12359           Accident 2008-10-19  United States
# 16369  20081012X91435           Accident 2008-10-10  United States
# 16370  20081011X02304           Accident 2008-10-10  United States
# 16412  20081002X13229           Accident 2008-10-01  United States
# 16418  20081006X60439           Accident 2008-09-30  United States
# 16438  20081004X12025           Accident 2008-09-27  United States
# 16472  20080922X01512           Accident 2008-09-20  United States
# 16474  20081010X43245           Accident 2008-09-20  United States
# 16480  20081003X16581           Accident 2008-09-19  United States
# 16507  20081017X43020           Accident 2008-09-14  United States
# ...

# %%
fatal_flights = real_df[real_df['Total_Fatal_Injuries'] > 0]

fatal_flights
# Out:
#            Event_Id_x Investigation_Type Event_Date        Country  \
# index
# 16395  20081006X90954           Accident 2008-10-05  United States
# 16857  20080731X01132           Accident 2008-07-27  United States
# 17011  20080715X01050           Accident 2008-07-05  United States
# 17028  20080711X01023           Accident 2008-07-02  United States
# 17117  20080710X01005           Accident 2008-06-21  United States
# 17152  20080623X00891           Accident 2008-06-17  United States
# 17212  20080611X00824           Accident 2008-06-07  United States
# 17237  20080611X00836           Accident 2008-06-03  United States
# 17261  20080606X00803           Accident 2008-05-30  United States
# 17289  20080529X00747           Accident 2008-05-25  United States
# 17367  20080521X00707           Accident 2008-05-12  United States
# 17392  20080515X00672           Accident 2008-05-09  United States
# 17460  20080505X00592           Accident 2008-04-28  United States
# ...

# %%
no_deaths['Investigation_Type'].value_counts()
# Out:
# Accident    36648
# Incident      960
# Name: Investigation_Type, dtype: int64

# %%
no_deaths['Aircraft_Damage'].value_counts()
# Out:
# Substantial    31766
# Destroyed       4613
# Minor           1229
# Name: Aircraft_Damage, dtype: int64

# %%
fatal_flights['Investigation_Type'].value_counts()
# Out:
# Accident    8797
# Incident       3
# Name: Investigation_Type, dtype: int64

# %%
fatal_flights['Aircraft_Damage'].value_counts()
# Out:
# Destroyed      7673
# Substantial    1066
# Minor            61
# Name: Aircraft_Damage, dtype: int64

# %%
real_df['Was_Fatal'] = real_df['Total_Fatal_Injuries']

# %%
fatal = np.array(real_df['Was_Fatal'].values.tolist())
print (fatal)
# Out:
# [0. 0. 0. ... 2. 4. 2.]

# %%
real_df['Was_Fatal'] = np.where(fatal > 0, 'Fatal', fatal).tolist()

# %%
new_fatal = np.array(real_df['Was_Fatal'].values.tolist())

new_fatal
# Out:
# array(['0.0', '0.0', '0.0', ..., 'Fatal', 'Fatal', 'Fatal'], dtype='<U5')

# %%
real_df['Was_Fatal'] = np.where(new_fatal == '0.0', 'Non-fatal', new_fatal).tolist()

# %%
real_df.head()
# Out:
#            Event_Id_x Investigation_Type Event_Date        Country  \
# index
# 16185  20081126X30503           Accident 2008-11-25  United States
# 16254  20081112X43029           Accident 2008-11-08  United States
# 16315  20081024X13647           Accident 2008-10-24  United States
# 16337  20081020X12359           Accident 2008-10-19  United States
# 16369  20081012X91435           Accident 2008-10-10  United States
#
#       Injury_Severity Aircraft_Damage    Make      Model Amateur_Built  \
# index
# 16185       Non-Fatal     Substantial   PIPER  PA-28-180            No
# 16254       Non-Fatal     Substantial   PIPER  PA-28-140            No
# 16315       Non-Fatal       Destroyed    RANS     S-12XL           Yes
# 16337       Non-Fatal     Substantial  CESSNA      A185F            No
# 16369       Non-Fatal     Substantial    BELL       206B            No
#
#        Number_Engines    ...     Total_Fatal_Injuries Total_Serious_Injuries  \
# index                    ...
# ...

# %%
real_df['Month'] = real_df['Event_Date'].dt.month

# %%
real_df.Month.value_counts()
# Out:
# 7     5616
# 8     5312
# 6     4972
# 5     4500
# 9     4377
# 4     3872
# 10    3510
# 3     3478
# 11    2845
# 2     2759
# 12    2606
# 1     2561
# Name: Month, dtype: int64

# %%
real_df['Season'] = ((real_df['Month']%12 + 3)//3)

# %%
real_df.Season.value_counts()
# Out:
# 3    15900
# 2    11850
# 4    10732
# 1     7926
# Name: Season, dtype: int64

# %%
real_df.Season.replace(1, 'Winter', inplace=True)
real_df.Season.replace(2, 'Spring', inplace=True)
real_df.Season.replace(3, 'Summer', inplace=True)
real_df.Season.replace(4, 'Fall', inplace=True)

# %%
real_df.Season.value_counts()
# Out:
# Summer    15900
# Spring    11850
# Fall      10732
# Winter     7926
# Name: Season, dtype: int64

# %%
fatal_crash_df = real_df[real_df['Was_Fatal'] == 'Fatal']

# %%
pd.value_counts(fatal_crash_df['Season']).plot.bar()
plt.xlabel('Season')
plt.ylabel('No. of Fatal Accidents')
plt.xticks(rotation=0)
plt.title("Fatal Accidents by Season")
# Out:
# Text(0.5,1,'Fatal Accidents by Season')

# %%
pd.value_counts(real_df['Season']).plot.bar()
plt.xlabel('Season')
plt.ylabel('No. of Accidents')
plt.xticks(rotation=0)
plt.title("Total Accidents by Season")
# Out:
# Text(0.5,1,'Total Accidents by Season')

# %% [markdown]
# #### MIGHT NOT BE USEFUL, MORE PEOPLE PROBABLY FLY OVERALL DURING THE SUMMER AND SPRING

# %% [markdown]
# ## UNEVEN SAMPLING -- CHECK HOW TO FIX (STRATIFY?)
#
# 80% OF ACCIDENTS AREN'T FATAL

# %%
no_injuries = real_df[real_df['Total_Uninjured'] == real_df['Total_Passengers']]

no_injuries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25589 entries, 16254 to 81891
# Data columns (total 24 columns):
# Event_Id_x                25589 non-null object
# Investigation_Type        25589 non-null object
# Event_Date                25589 non-null datetime64[ns]
# Country                   25589 non-null object
# Injury_Severity           25589 non-null object
# Aircraft_Damage           25589 non-null object
# Make                      25589 non-null object
# Model                     25589 non-null object
# Amateur_Built             25589 non-null object
# Number_Engines            25589 non-null float64
# Engine_Type               25589 non-null object
# Flight_Purpose            25589 non-null object
# Total_Fatal_Injuries      25589 non-null float64
# Total_Serious_Injuries    25589 non-null float64
# Total_Minor_Injuries      25589 non-null float64
# Total_Uninjured           25589 non-null float64
# Weather_Condition         25589 non-null object
# ...

# %% [markdown]
# ## GUNZIP A CSV FILE

# %%
## gzip -l filename

# %% [markdown]
# ## UNZIP A GUNZIP

# %%
## gunzip filename

# %% [markdown]
# # WORKING WITH PSQL

# %%
# ssx = StandardScaler()

# x_scaled = ssx.fit_transform(X_TRAIN)
# X_test_scaled = ssx.transform(X_test)
